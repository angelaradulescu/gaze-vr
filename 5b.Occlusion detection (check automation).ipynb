# %% [markdown]
# The goal of this notebook is to check the automated occlusion annotations produced by the Unity VizTest tool built by Scott MacDonald against the ones human annotators did by hand. See this Quip document for details: https://fb.quip.com/GuSYAz9JosOv

# %%
import numpy as np
import pandas as pd
import visual_search_load
import re
import visual_search_objects

# %% [markdown]
# ### Preprocess annotation results for one scene.

# %%
## Set directories. 
# Main data directory. 
direc = '/Users/angelaradulescu/Dropbox/NYU/Research/TaskVR/VisualSearchRawData/'
# Hand annotations directory. 
hand_occlusion_direc = '/Users/angelaradulescu/Dropbox/NYU/Research/TaskVR/VisualSearchGazeData/occlusion_hand_annotated_scenes/'
# VizTest automated annotations directory. 
auto_occlusion_direc = '/Users/angelaradulescu/Dropbox/NYU/Research/TaskVR/Unity_projects/Occlusion_tagging/VizTestOutput/'
data_direc, participant_list = visual_search_load.get_direc_participants('Expt2', direc)
# Locations directory. 
locations_direc = '/Users/angelaradulescu/Dropbox/NYU/Research/TaskVR/VisualSearchGazeData/location/'

## Load locations.
locations = pd.read_csv(locations_direc + 'location_all_objects.csv')

## Grab all scenes.
indexes = np.unique(locations['scene'].values, return_index=True)[1]
all_scenes = [locations['scene'].values[index] for index in sorted(indexes)]

# %%
## Select scene. 
scene = 'Bathroom Location 3 Trial 7'
# scene = 'Guest Bedroom Location 5 Trial 10'

# %%
## Get manual annotation. 
objects = visual_search_load.get_all_objects(data_direc, scene)
locations_str = visual_search_load.get_object_locations(data_direc, scene)
locations_arr = visual_search_objects.parse_locations(locations_str)
hand_occlusion_labels = pd.read_csv(hand_occlusion_direc + scene + '.csv') 
hand_occlusion_labels = hand_occlusion_labels.drop(columns='Unnamed: 0')
hand_occlusion_labels.insert(0, 'object', value=objects)
hand_occlusion_labels.insert(2, 'location', value=locations_arr)

hand_occlusion_labels[hand_occlusion_labels['object'] == 'Soccer Ball']
hand_occlusion_labels.head(5)
# Out:
#       object  occluded                         location
# 0     Book 1       0.0  [-4.763133, 0.761089, 6.695295]
# 1  Paper Box       0.0  [-5.058631, 0.133333, 8.123557]
# 2     Vase 1       1.0   [-1.987741, 0.193434, 8.58199]
# 3    Block 2       1.0  [-2.070976, 0.174345, 8.427336]
# 4     Tomato       0.0  [-4.600757, 0.798804, 6.620316]

# %%
## Get auto annotation. 
auto_occlusion_labels = visual_search_objects.parse_auto_occlusion_tags(auto_occlusion_direc + 'results_' + scene)
auto_occlusion_labels.head(5)
# Out:
#         object  occluded                location
# 0    Pizza Box         0   [-3.36, 0.028, 7.816]
# 1          Pen         0  [-1.763, 0.004, 6.907]
# 2     Crayon 3         1  [-3.361, 0.005, 8.237]
# 3  Rubber Duck         0  [-3.134, 0.065, 7.161]
# 4      Block 3         0  [-4.391, 0.029, 7.618]

# %%
## Combine auto and hand annotations.
combined_labels = visual_search_objects.match_occlusion_labels(auto_occlusion_labels, hand_occlusion_labels)
combined_labels.head(10)
# Out:
#          object  occluded                         location  \
# 0        Book 1       0.0  [-4.763133, 0.761089, 6.695295]
# 1     Paper Box       0.0  [-5.058631, 0.133333, 8.123557]
# 2        Vase 1       1.0   [-1.987741, 0.193434, 8.58199]
# 3       Block 2       1.0  [-2.070976, 0.174345, 8.427336]
# 4        Tomato       0.0  [-4.600757, 0.798804, 6.620316]
# 5      Scissors       0.0  [-5.487945, 0.124983, 8.110414]
# 6  Dodecahedron       0.0  [-5.594612, 0.278637, 8.192053]
# 7      Crayon 6       1.0  [-2.216746, 0.182995, 8.570617]
# 8        Laptop       0.0   [-3.683148, 0.88329, 8.172914]
# 9     Picture 2       1.0   [-4.971868, 0.17841, 6.742446]
#
#   nearest_auto_annot_obj nearest_occluded        nearest_location
# 0                 Book 1                0  [-4.763, 0.761, 6.695]
# 1              Paper Box                0  [-5.059, 0.133, 8.124]
# 2                 Vase 1                0  [-1.988, 0.193, 8.582]
# 3                Block 2                1  [-2.071, 0.174, 8.427]
# 4            Tomato_LOD2                0   [-4.601, 0.799, 6.62]
# 5               Scissors                0   [-5.488, 0.125, 8.11]
# 6           Dodecahedron                0  [-5.595, 0.279, 8.192]
# 7               Crayon 6                1  [-2.217, 0.183, 8.571]
# 8                 laptop                0  [-3.683, 0.883, 8.173]
# 9              Picture 2                1  [-4.972, 0.178, 6.742]

# %%
## Compute agreement. 
# Overall.
a = np.round(np.mean(combined_labels['occluded'].values == combined_labels['nearest_occluded'].values),3)
print('overall agreement between human and tool: ' + str(a))
# On occlusions.
idx = np.where(combined_labels['occluded'].values == 1)[0]
a = np.round(np.sum(combined_labels.loc[idx]['nearest_occluded'].values)/len(idx),3)
so = np.sum(combined_labels.loc[idx]['nearest_occluded'].values)
print('number of occlusions: ' + str(len(idx)))
print('agreement on occlusions: ' + str(a) + ', ' + str(so) + '/' + str(len(idx)))
# Out:
# overall agreement between human and tool: 0.932
# number of occlusions: 11
# agreement on occlusions: 0.818, 9/11

# %% [markdown]
# ### Examine fail cases.

# %%
x = np.where(hand_occlusion_labels['occluded'].values != hand_occlusion_labels['nearest_occluded'].values)[0]
hand_occlusion_labels.loc[x]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nearest_occluded'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-f0be8a82ca4f> in <module>
# ----> 1 x = np.where(hand_occlusion_labels['occluded'].values != hand_occlusion_labels['nearest_occluded'].values)[0]
#       2 hand_occlusion_labels.loc[x]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'nearest_occluded'

# %%
hand_occlusion_labels[hand_occlusion_labels['nearest_auto_annot_obj'] == 'Book 1']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nearest_auto_annot_obj'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-26d1855b9ca5> in <module>
# ----> 1 hand_occlusion_labels[hand_occlusion_labels['nearest_auto_annot_obj'] == 'Book 1']
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'nearest_auto_annot_obj'

# %%
print(auto_occlusion_labels[auto_occlusion_labels['object'] == 'Book 1'])
auto_occlusion_labels[(auto_occlusion_labels['unique'] > 20) & (auto_occlusion_labels['unique'] < 30)]
# Out:
# Empty DataFrame
# Columns: [object, occluded, location, unique]
# Index: []
#                      object  occluded                location  unique
# 22                Clipboard         1   [0.598, 0.785, 6.642]      21
# 23                  Donut 2         1    [1.588, 0.62, 8.207]      22
# 24           Goods-Tin_LOD2         1  [1.664, 0.408, 10.735]      23
# 25                Goods-Tin         1  [1.664, 0.408, 10.735]      23
# 26                Goods-Tin         1  [1.664, 0.408, 10.735]      23
# 27               Magazine 1         1   [1.364, 0.235, 6.645]      24
# 28  ITM3D_CoconutHalf2_LOD2         1  [2.658, 0.494, 10.483]      25
# 29       ITM3D_CoconutHalf2         1  [2.658, 0.494, 10.483]      25
# 30       ITM3D_CoconutHalf2         1  [2.658, 0.494, 10.483]      25
# 31                 Scissors         1   [1.446, 0.606, 9.114]      26
# 32              Rubber Duck         1   [0.406, 0.785, 9.014]      27
# 33                 Crayon 6         1  [1.428, 0.381, 10.726]      28
# 34                 Soda Can         1   [1.842, 0.787, 6.682]      29

# %%
target_loc = np.array([5.539, 0.733, 0.383])
np.where(np.sum(np.vstack(auto_occlusion_labels['location'].values) == target_loc, axis=1))[0]
# Out:
# array([], dtype=int64)

# %% [markdown]
# ### Introduce auto occlusion tags in the location files.

# %%
def generate_occlusion_labels(data_direc, auto_occlusion_direc, locations):
    
    ## Make a copy of the dataframe.
    locations_tagged = locations.copy()
    locations_tagged['occluded'] = np.nan
    
    ## Grab all scenes.
    indexes = np.unique(locations['scene'].values, return_index=True)[1]
    all_scenes = [locations['scene'].values[index] for index in sorted(indexes)]
    
    df_list = []
    
    ## Loop through scenes.
    for scene in all_scenes:
        
        print(scene)
        
        ## Grab auto annotations for this scene.
        auto_occlusion_labels = visual_search_objects.parse_auto_occlusion_tags(auto_occlusion_direc + 'results_' + scene)
        
        if (scene == 'Guest Bedroom Location 5 Trial 10'):
            print('problem scene')
            hand_occlusion_labels = pd.read_csv(hand_occlusion_direc + scene + '.csv')
        
        ## Subset locations for this scene.
        locations_scene = locations[locations['scene'] == scene].reset_index(drop=True)
        locations_str = visual_search_load.get_object_locations(data_direc, scene)
        locations_arr = visual_search_objects.parse_locations(locations_str)
        locations_scene['location'] = locations_arr
        
        ## Combine manual and annotated 
        combined = visual_search_objects.match_occlusion_labels(auto_occlusion_labels, locations_scene)
        print('target occluded? ' + str(combined['nearest_occluded'].values[0]))
        print('percentage occluded: ' + str(np.sum(combined['nearest_occluded'].values)/len(locations_scene)))
        locations_scene['occluded'] = combined['nearest_occluded'].values
        
        if (scene == 'Guest Bedroom Location 5 Trial 10'):
            print('replacing automated labels with hand labels')
            locations_scene['occluded'] = hand_occlusion_labels['occluded'].values
           
        df_list.append(locations_scene)
    
    locations_tagged = pd.concat(df_list)    
         
    return locations_tagged

locations_tagged = generate_occlusion_labels(data_direc, auto_occlusion_direc, locations)
locations_tagged.to_csv(locations_direc+'location_all_objects_tagged.csv', index=False)
# Out:
# Kitchen Location 1 Trial 9
# target occluded? 0
# percentage occluded: 0.0851063829787234
# Kitchen Location 2 Trial 3
# target occluded? 0
# percentage occluded: 0.15789473684210525
# Kitchen Location 2 Trial 4
# target occluded? 0
# percentage occluded: 0.10869565217391304
# Living Room Location 4 Trial 5
# target occluded? 0
# percentage occluded: 0.32710280373831774
# Studio Location 3 Trial 3
# target occluded? 0
# percentage occluded: 0.078125
# Studio Location 5 Trial 3
# target occluded? 0
# percentage occluded: 0.1791044776119403
# Bedroom Location 5 Trial 5
# target occluded? 0
# percentage occluded: 0.2236842105263158
# Guest Bedroom Location 3 Trial 5
# target occluded? 0
# percentage occluded: 0.0967741935483871
# Living Room Location 5 Trial 10
# target occluded? 0
# percentage occluded: 0.32142857142857145
# Bedroom Location 1 Trial 8
# target occluded? 0
# percentage occluded: 0.0821917808219178
# Bedroom Location 4 Trial 2
# target occluded? 0
# percentage occluded: 0.13157894736842105
# Studio Location 2 Trial 1
# target occluded? 0
# percentage occluded: 0.19117647058823528
# Guest Bedroom Location 3 Trial 7
# target occluded? 0
# percentage occluded: 0.042105263157894736
# Kitchen Location 3 Trial 10
# target occluded? 0
# percentage occluded: 0.30851063829787234
# Guest Bedroom Location 1 Trial 9
# target occluded? 0
# percentage occluded: 0.18556701030927836
# Guest Bedroom Location 3 Trial 8
# target occluded? 0
# percentage occluded: 0.07368421052631578
# Guest Bedroom Location 5 Trial 10
# problem scene
# target occluded? 1
# percentage occluded: 1.0
# replacing automated labels with hand labels
# Bathroom Location 3 Trial 7
# target occluded? 0
# percentage occluded: 0.1864406779661017
# Bathroom Location 1 Trial 8
# target occluded? 0
# percentage occluded: 0.29310344827586204
# Living Room Location 3 Trial 8
# target occluded? 0
# percentage occluded: 0.20535714285714285
# Studio Location 4 Trial 9
# target occluded? 0
# percentage occluded: 0.06153846153846154
# Kitchen Location 2 Trial 2
# target occluded? 0
# percentage occluded: 0.12631578947368421
# Living Room Location 1 Trial 2
# target occluded? 0
# percentage occluded: 0.21818181818181817
# Kitchen Location 2 Trial 8
# target occluded? 0
# percentage occluded: 0.14285714285714285
# Bathroom Location 3 Trial 3
# target occluded? 0
# percentage occluded: 0.13333333333333333
# Kitchen Location 5 Trial 4
# target occluded? 0
# percentage occluded: 0.16129032258064516
# Kitchen Location 4 Trial 6
# target occluded? 0
# percentage occluded: 0.20833333333333334
# Bedroom Location 2 Trial 1
# target occluded? 0
# percentage occluded: 0.19736842105263158
# Kitchen Location 5 Trial 8
# target occluded? 0
# percentage occluded: 0.10416666666666667
# Studio Location 4 Trial 1
# target occluded? 0
# percentage occluded: 0.09230769230769231
# Guest Bedroom Location 5 Trial 1
# target occluded? 0
# percentage occluded: 0.0625
# Kitchen Location 5 Trial 7
# target occluded? 0
# percentage occluded: 0.11578947368421053
# Guest Bedroom Location 1 Trial 8
# target occluded? 0
# percentage occluded: 0.1702127659574468
# Studio Location 3 Trial 8
# target occluded? 0
# percentage occluded: 0.0625
# Bedroom Location 4 Trial 9
# target occluded? 0
# percentage occluded: 0.12162162162162163
# Guest Bedroom Location 4 Trial 2
# target occluded? 0
# percentage occluded: 0.2127659574468085
# Living Room Location 1 Trial 8
# target occluded? 0
# percentage occluded: 0.1834862385321101
# Guest Bedroom Location 3 Trial 9
# target occluded? 0
# percentage occluded: 0.12087912087912088
# Living Room Location 5 Trial 5
# target occluded? 0
# percentage occluded: 0.24545454545454545
# Living Room Location 2 Trial 9
# target occluded? 0
# percentage occluded: 0.2818181818181818
# Bathroom Location 3 Trial 4
# target occluded? 0
# percentage occluded: 0.25806451612903225
# Bedroom Location 2 Trial 4
# target occluded? 0
# percentage occluded: 0.1917808219178082
# Studio Location 2 Trial 7
# target occluded? 0
# percentage occluded: 0.21212121212121213
# Bedroom Location 4 Trial 8
# target occluded? 0
# percentage occluded: 0.18421052631578946
# Bedroom Location 5 Trial 7
# target occluded? 0
# percentage occluded: 0.2222222222222222
# Bedroom Location 2 Trial 3
# target occluded? 0
# percentage occluded: 0.24324324324324326
# Guest Bedroom Location 2 Trial 8
# target occluded? 0
# percentage occluded: 0.21052631578947367
# Bedroom Location 1 Trial 10
# target occluded? 0
# percentage occluded: 0.136986301369863
# Studio Location 2 Trial 10
# target occluded? 0
# percentage occluded: 0.208955223880597
# Guest Bedroom Location 1 Trial 6
# target occluded? 0
# percentage occluded: 0.24468085106382978
# Guest Bedroom Location 3 Trial 2
# target occluded? 0
# percentage occluded: 0.06521739130434782
# Kitchen Location 3 Trial 9
# target occluded? 0
# percentage occluded: 0.2
# Kitchen Location 1 Trial 3
# target occluded? 0
# percentage occluded: 0.13043478260869565
# Living Room Location 2 Trial 3
# target occluded? 0
# percentage occluded: 0.2636363636363636
# Studio Location 1 Trial 7
# target occluded? 0
# percentage occluded: 0.043478260869565216
# Kitchen Location 1 Trial 7
# target occluded? 0
# percentage occluded: 0.13186813186813187
# Bedroom Location 5 Trial 6
# target occluded? 0
# percentage occluded: 0.27631578947368424
# Kitchen Location 3 Trial 5
# target occluded? 0
# percentage occluded: 0.22340425531914893
# Bedroom Location 4 Trial 5
# target occluded? 0
# percentage occluded: 0.14666666666666667
# Guest Bedroom Location 4 Trial 4
# target occluded? 0
# percentage occluded: 0.1595744680851064
# Living Room Location 3 Trial 10
# target occluded? 0
# percentage occluded: 0.21621621621621623
# Studio Location 1 Trial 8
# target occluded? 0
# percentage occluded: 0.09090909090909091
# Bedroom Location 1 Trial 6
# target occluded? 0
# percentage occluded: 0.09090909090909091
# Studio Location 5 Trial 5
# target occluded? 0
# percentage occluded: 0.17391304347826086
# Studio Location 3 Trial 10
# target occluded? 0
# percentage occluded: 0.046153846153846156
# Bedroom Location 3 Trial 4
# target occluded? 0
# percentage occluded: 0.1038961038961039
# Living Room Location 2 Trial 7
# target occluded? 0
# percentage occluded: 0.3181818181818182
# Kitchen Location 5 Trial 3
# target occluded? 0
# percentage occluded: 0.13402061855670103
# Guest Bedroom Location 5 Trial 4
# target occluded? 0
# percentage occluded: 0.08421052631578947
# Bedroom Location 4 Trial 1
# target occluded? 0
# percentage occluded: 0.14864864864864866
# Bathroom Location 2 Trial 5
# target occluded? 0
# percentage occluded: 0.2542372881355932
# Guest Bedroom Location 4 Trial 9
# target occluded? 0
# percentage occluded: 0.22105263157894736
# Guest Bedroom Location 2 Trial 5
# target occluded? 0
# percentage occluded: 0.1875
# Guest Bedroom Location 5 Trial 3
# target occluded? 0
# percentage occluded: 0.11458333333333333
# Kitchen Location 3 Trial 1
# target occluded? 0
# percentage occluded: 0.23404255319148937
# Studio Location 4 Trial 7
# target occluded? 0
# percentage occluded: 0.15625
# Living Room Location 5 Trial 4
# target occluded? 0
# percentage occluded: 0.26785714285714285
# Guest Bedroom Location 3 Trial 1
# target occluded? 0
# percentage occluded: 0.10752688172043011
# Guest Bedroom Location 3 Trial 10
# target occluded? 0
# percentage occluded: 0.08602150537634409
# Bathroom Location 2 Trial 3
# target occluded? 0
# percentage occluded: 0.2459016393442623
# Bedroom Location 5 Trial 3
# target occluded? 0
# percentage occluded: 0.2054794520547945
# Studio Location 3 Trial 6
# target occluded? 0
# percentage occluded: 0.109375
# Bathroom Location 4 Trial 7
# target occluded? 0
# percentage occluded: 0.3389830508474576
# Bathroom Location 3 Trial 5
# target occluded? 0
# percentage occluded: 0.1864406779661017
# Bathroom Location 5 Trial 7
# target occluded? 0
# percentage occluded: 0.09090909090909091
# Living Room Location 5 Trial 9
# target occluded? 0
# percentage occluded: 0.34545454545454546
# Bedroom Location 3 Trial 9
# target occluded? 0
# percentage occluded: 0.1038961038961039
# Bedroom Location 1 Trial 2
# target occluded? 0
# percentage occluded: 0.11842105263157894
# Studio Location 3 Trial 2
# target occluded? 0
# percentage occluded: 0.07462686567164178
# Living Room Location 2 Trial 1
# target occluded? 0
# percentage occluded: 0.2743362831858407
# Guest Bedroom Location 4 Trial 8
# target occluded? 0
# percentage occluded: 0.16304347826086957
# Guest Bedroom Location 4 Trial 6
# target occluded? 0
# percentage occluded: 0.1276595744680851
# Kitchen Location 4 Trial 10
# target occluded? 0
# percentage occluded: 0.1827956989247312
# Living Room Location 5 Trial 6
# target occluded? 0
# percentage occluded: 0.2920353982300885
# Studio Location 4 Trial 10
# target occluded? 0
# percentage occluded: 0.09230769230769231
# Studio Location 2 Trial 3
# target occluded? 0
# percentage occluded: 0.14925373134328357
# Bathroom Location 1 Trial 7
# target occluded? 0
# percentage occluded: 0.1864406779661017
# Studio Location 2 Trial 2
# target occluded? 0
# percentage occluded: 0.203125
# Studio Location 5 Trial 8
# target occluded? 0
# percentage occluded: 0.171875
# Kitchen Location 4 Trial 8
# target occluded? 0
# percentage occluded: 0.18947368421052632
# Living Room Location 2 Trial 8
# target occluded? 0
# percentage occluded: 0.3211009174311927
# Bathroom Location 3 Trial 8
# target occluded? 0
# percentage occluded: 0.1896551724137931
# Guest Bedroom Location 2 Trial 3
# target occluded? 0
# percentage occluded: 0.17708333333333334
# Living Room Location 3 Trial 6
# target occluded? 0
# percentage occluded: 0.16964285714285715
# Bathroom Location 1 Trial 2
# target occluded? 0
# percentage occluded: 0.21311475409836064
# Bedroom Location 3 Trial 7
# target occluded? 0
# percentage occluded: 0.08
# Bathroom Location 5 Trial 5
# target occluded? 0
# percentage occluded: 0.12903225806451613
# Bedroom Location 2 Trial 5
# target occluded? 0
# percentage occluded: 0.2054794520547945
# Living Room Location 5 Trial 8
# target occluded? 0
# percentage occluded: 0.32727272727272727
# Bathroom Location 1 Trial 3
# target occluded? 0
# percentage occluded: 0.21428571428571427
# Bedroom Location 2 Trial 10
# target occluded? 0
# percentage occluded: 0.1891891891891892
# Living Room Location 1 Trial 1
# target occluded? 0
# percentage occluded: 0.13274336283185842
# Kitchen Location 5 Trial 1
# target occluded? 0
# percentage occluded: 0.1956521739130435
# Studio Location 3 Trial 9
# target occluded? 0
# percentage occluded: 0.08695652173913043
# Bathroom Location 5 Trial 4
# target occluded? 0
# percentage occluded: 0.08196721311475409
# Living Room Location 4 Trial 9
# target occluded? 0
# percentage occluded: 0.25
# Bathroom Location 2 Trial 2
# target occluded? 0
# percentage occluded: 0.27586206896551724
# Living Room Location 2 Trial 5
# target occluded? 0
# percentage occluded: 0.34234234234234234
# Studio Location 3 Trial 4
# target occluded? 0
# percentage occluded: 0.07462686567164178
# Bedroom Location 3 Trial 8
# target occluded? 0
# percentage occluded: 0.19480519480519481
# Kitchen Location 4 Trial 9
# target occluded? 0
# percentage occluded: 0.2391304347826087
# Kitchen Location 5 Trial 9
# target occluded? 0
# percentage occluded: 0.14736842105263157
# Living Room Location 3 Trial 9
# target occluded? 0
# percentage occluded: 0.22727272727272727
# Kitchen Location 3 Trial 4
# target occluded? 0
# percentage occluded: 0.2765957446808511
# Studio Location 5 Trial 9
# target occluded? 0
# percentage occluded: 0.07352941176470588
# Bathroom Location 3 Trial 6
# target occluded? 0
# percentage occluded: 0.25
# Bedroom Location 5 Trial 2
# target occluded? 0
# percentage occluded: 0.17333333333333334
# Bedroom Location 1 Trial 1
# target occluded? 0
# percentage occluded: 0.08108108108108109
# Kitchen Location 3 Trial 7
# target occluded? 0
# percentage occluded: 0.22340425531914893
# Studio Location 3 Trial 7
# target occluded? 0
# percentage occluded: 0.11940298507462686
# Bathroom Location 2 Trial 10
# target occluded? 0
# percentage occluded: 0.21666666666666667
# Studio Location 3 Trial 5
# target occluded? 0
# percentage occluded: 0.05970149253731343
# Living Room Location 2 Trial 2
# target occluded? 0
# percentage occluded: 0.2702702702702703
# Guest Bedroom Location 2 Trial 7
# target occluded? 0
# percentage occluded: 0.1368421052631579
# Guest Bedroom Location 2 Trial 10
# target occluded? 0
# percentage occluded: 0.16304347826086957
# Living Room Location 4 Trial 6
# target occluded? 0
# percentage occluded: 0.33035714285714285
# Living Room Location 4 Trial 10
# target occluded? 1
# percentage occluded: 0.32727272727272727
# Kitchen Location 1 Trial 10
# target occluded? 0
# percentage occluded: 0.11702127659574468
# Bedroom Location 4 Trial 3
# target occluded? 0
# percentage occluded: 0.13157894736842105
# Kitchen Location 1 Trial 2
# target occluded? 0
# percentage occluded: 0.08602150537634409
# Bedroom Location 2 Trial 7
# target occluded? 0
# percentage occluded: 0.16216216216216217
# Studio Location 1 Trial 9
# target occluded? 0
# percentage occluded: 0.030303030303030304
# Kitchen Location 5 Trial 2
# target occluded? 0
# percentage occluded: 0.1702127659574468
# Bathroom Location 3 Trial 9
# target occluded? 0
# percentage occluded: 0.26666666666666666
# Bedroom Location 1 Trial 3
# target occluded? 0
# percentage occluded: 0.039473684210526314
# Studio Location 2 Trial 9
# target occluded? 0
# percentage occluded: 0.15942028985507245
# Bedroom Location 5 Trial 4
# target occluded? 0
# percentage occluded: 0.20270270270270271
# Bathroom Location 4 Trial 10
# target occluded? 0
# percentage occluded: 0.23333333333333334
# Bathroom Location 1 Trial 6
# target occluded? 0
# percentage occluded: 0.14516129032258066
# Bathroom Location 2 Trial 8
# target occluded? 0
# percentage occluded: 0.29508196721311475
# Kitchen Location 2 Trial 6
# target occluded? 0
# percentage occluded: 0.19148936170212766
# Studio Location 2 Trial 5
# target occluded? 0
# percentage occluded: 0.12903225806451613
# Bedroom Location 4 Trial 7
# target occluded? 0
# percentage occluded: 0.17567567567567569
# Kitchen Location 1 Trial 6
# target occluded? 0
# percentage occluded: 0.1134020618556701
# Bedroom Location 3 Trial 10
# target occluded? 0
# percentage occluded: 0.14666666666666667
# Living Room Location 1 Trial 10
# target occluded? 0
# percentage occluded: 0.09174311926605505
# Bathroom Location 2 Trial 7
# target occluded? 0
# percentage occluded: 0.288135593220339
# Guest Bedroom Location 1 Trial 1
# target occluded? 0
# percentage occluded: 0.22105263157894736
# Living Room Location 4 Trial 1
# target occluded? 0
# percentage occluded: 0.26126126126126126
# Living Room Location 5 Trial 1
# target occluded? 0
# percentage occluded: 0.3
# Bathroom Location 5 Trial 9
# target occluded? 0
# percentage occluded: 0.18032786885245902
# Kitchen Location 1 Trial 5
# target occluded? 0
# percentage occluded: 0.09278350515463918
# Guest Bedroom Location 1 Trial 2
# target occluded? 0
# percentage occluded: 0.20833333333333334
# Studio Location 1 Trial 10
# target occluded? 0
# percentage occluded: 0.06153846153846154
# Living Room Location 2 Trial 6
# target occluded? 0
# percentage occluded: 0.375
# Guest Bedroom Location 4 Trial 7
# target occluded? 0
# percentage occluded: 0.14893617021276595
# Studio Location 1 Trial 6
# target occluded? 0
# percentage occluded: 0.06060606060606061
# Studio Location 1 Trial 5
# target occluded? 0
# percentage occluded: 0.07575757575757576
# Guest Bedroom Location 1 Trial 3
# target occluded? 0
# percentage occluded: 0.22448979591836735
# Bathroom Location 1 Trial 5
# target occluded? 0
# percentage occluded: 0.21428571428571427
# Living Room Location 2 Trial 4
# target occluded? 0
# percentage occluded: 0.3482142857142857
# Bathroom Location 5 Trial 1
# target occluded? 0
# percentage occluded: 0.14754098360655737
# Bedroom Location 2 Trial 8
# target occluded? 0
# percentage occluded: 0.22077922077922077
# Living Room Location 5 Trial 3
# target occluded? 0
# percentage occluded: 0.3
# Bathroom Location 5 Trial 3
# target occluded? 0
# percentage occluded: 0.07142857142857142
# Bathroom Location 2 Trial 1
# target occluded? 0
# percentage occluded: 0.3050847457627119
# Guest Bedroom Location 1 Trial 5
# target occluded? 0
# percentage occluded: 0.1875
# Bathroom Location 3 Trial 10
# target occluded? 0
# percentage occluded: 0.25806451612903225
# Bedroom Location 5 Trial 10
# target occluded? 0
# percentage occluded: 0.19736842105263158
# Guest Bedroom Location 4 Trial 5
# target occluded? 0
# percentage occluded: 0.1368421052631579
# Living Room Location 4 Trial 7
# target occluded? 0
# percentage occluded: 0.3211009174311927
# Guest Bedroom Location 2 Trial 1
# target occluded? 0
# percentage occluded: 0.1276595744680851
# Living Room Location 4 Trial 3
# target occluded? 0
# percentage occluded: 0.3392857142857143
# Bathroom Location 5 Trial 10
# target occluded? 0
# percentage occluded: 0.13333333333333333
# Living Room Location 4 Trial 4
# target occluded? 0
# percentage occluded: 0.33035714285714285
# Studio Location 2 Trial 6
# target occluded? 0
# percentage occluded: 0.15151515151515152
# Living Room Location 1 Trial 3
# target occluded? 0
# percentage occluded: 0.0990990990990991
# Living Room Location 1 Trial 6
# target occluded? 0
# percentage occluded: 0.13274336283185842
# Kitchen Location 2 Trial 10
# target occluded? 0
# percentage occluded: 0.19148936170212766
# Kitchen Location 3 Trial 2
# target occluded? 0
# percentage occluded: 0.21978021978021978
# Bathroom Location 4 Trial 1
# target occluded? 0
# percentage occluded: 0.2807017543859649
# Bathroom Location 4 Trial 8
# target occluded? 0
# percentage occluded: 0.25862068965517243
# Studio Location 5 Trial 10
# target occluded? 0
# percentage occluded: 0.10144927536231885
# Bedroom Location 2 Trial 9
# target occluded? 0
# percentage occluded: 0.19444444444444445
# Guest Bedroom Location 3 Trial 3
# target occluded? 0
# percentage occluded: 0.042105263157894736
# Studio Location 4 Trial 2
# target occluded? 0
# percentage occluded: 0.11764705882352941
# Guest Bedroom Location 3 Trial 4
# target occluded? 0
# percentage occluded: 0.06521739130434782
# Guest Bedroom Location 2 Trial 4
# target occluded? 0
# percentage occluded: 0.2
# Living Room Location 3 Trial 5
# target occluded? 1
# percentage occluded: 0.2
# Studio Location 4 Trial 5
# target occluded? 0
# percentage occluded: 0.17647058823529413
# Kitchen Location 4 Trial 5
# target occluded? 0
# percentage occluded: 0.12903225806451613
# Guest Bedroom Location 5 Trial 8
# target occluded? 0
# percentage occluded: 0.07608695652173914
# Bedroom Location 5 Trial 9
# target occluded? 0
# percentage occluded: 0.19736842105263158
# Kitchen Location 4 Trial 4
# target occluded? 0
# percentage occluded: 0.1595744680851064
# Studio Location 4 Trial 4
# target occluded? 0
# percentage occluded: 0.1111111111111111
# Kitchen Location 1 Trial 1
# target occluded? 0
# percentage occluded: 0.10638297872340426
# Kitchen Location 1 Trial 8
# target occluded? 0
# percentage occluded: 0.10752688172043011
# Bathroom Location 5 Trial 6
# target occluded? 0
# percentage occluded: 0.09836065573770492
# Bedroom Location 3 Trial 3
# target occluded? 0
# percentage occluded: 0.09333333333333334
# Bathroom Location 4 Trial 5
# target occluded? 0
# percentage occluded: 0.25806451612903225
# Bathroom Location 2 Trial 9
# target occluded? 0
# percentage occluded: 0.23333333333333334
# Living Room Location 5 Trial 2
# target occluded? 0
# percentage occluded: 0.2743362831858407
# Bedroom Location 4 Trial 10
# target occluded? 0
# percentage occluded: 0.14864864864864866
# Kitchen Location 5 Trial 5
# target occluded? 0
# percentage occluded: 0.14285714285714285
# Bedroom Location 5 Trial 1
# target occluded? 0
# percentage occluded: 0.23684210526315788
# Bedroom Location 5 Trial 8
# target occluded? 0
# percentage occluded: 0.19736842105263158
# Bedroom Location 3 Trial 6
# target occluded? 0
# percentage occluded: 0.10666666666666667
# Bathroom Location 4 Trial 4
# target occluded? 0
# percentage occluded: 0.22033898305084745
# Kitchen Location 2 Trial 7
# target occluded? 0
# percentage occluded: 0.17582417582417584
# Guest Bedroom Location 4 Trial 10
# target occluded? 0
# percentage occluded: 0.11578947368421053
# Guest Bedroom Location 2 Trial 6
# target occluded? 0
# percentage occluded: 0.1702127659574468
# Bathroom Location 5 Trial 8
# target occluded? 0
# percentage occluded: 0.22580645161290322
# Studio Location 1 Trial 4
# target occluded? 0
# percentage occluded: 0.04411764705882353
# Bathroom Location 2 Trial 4
# target occluded? 0
# percentage occluded: 0.22580645161290322
# Living Room Location 5 Trial 7
# target occluded? 0
# percentage occluded: 0.35135135135135137
# Bedroom Location 3 Trial 5
# target occluded? 0
# percentage occluded: 0.10666666666666667
# Guest Bedroom Location 4 Trial 1
# target occluded? 0
# percentage occluded: 0.18947368421052632
# Kitchen Location 4 Trial 1
# target occluded? 0
# percentage occluded: 0.1595744680851064
# Guest Bedroom Location 5 Trial 9
# target occluded? 0
# percentage occluded: 0.09473684210526316
# Bathroom Location 4 Trial 9
# target occluded? 0
# percentage occluded: 0.25
# Kitchen Location 5 Trial 10
# target occluded? 0
# percentage occluded: 0.17204301075268819
# Studio Location 2 Trial 8
# target occluded? 0
# percentage occluded: 0.23529411764705882
# Bathroom Location 3 Trial 1
# target occluded? 0
# percentage occluded: 0.25806451612903225
# Studio Location 5 Trial 2
# target occluded? 0
# percentage occluded: 0.21739130434782608
# Studio Location 4 Trial 3
# target occluded? 0
# percentage occluded: 0.11428571428571428
# Living Room Location 3 Trial 7
# target occluded? 0
# percentage occluded: 0.25225225225225223
# Studio Location 1 Trial 1
# target occluded? 0
# percentage occluded: 0.03076923076923077
# Bathroom Location 2 Trial 6
# target occluded? 0
# percentage occluded: 0.24561403508771928
# Kitchen Location 4 Trial 7
# target occluded? 0
# percentage occluded: 0.17708333333333334
# Bathroom Location 5 Trial 2
# target occluded? 0
# percentage occluded: 0.14516129032258066
# Studio Location 3 Trial 1
# target occluded? 0
# percentage occluded: 0.046153846153846156
# Kitchen Location 2 Trial 9
# target occluded? 0
# percentage occluded: 0.18556701030927836
# Living Room Location 3 Trial 2
# target occluded? 0
# percentage occluded: 0.17117117117117117
# Guest Bedroom Location 5 Trial 2
# target occluded? 0
# percentage occluded: 0.06315789473684211
# Guest Bedroom Location 5 Trial 6
# target occluded? 0
# percentage occluded: 0.05263157894736842
# Kitchen Location 2 Trial 1
# target occluded? 0
# percentage occluded: 0.14583333333333334
# Studio Location 4 Trial 6
# target occluded? 0
# percentage occluded: 0.09836065573770492
# Bathroom Location 1 Trial 9
# target occluded? 0
# percentage occluded: 0.2698412698412698
# Bathroom Location 4 Trial 2
# target occluded? 0
# percentage occluded: 0.18333333333333332
# Guest Bedroom Location 5 Trial 5
# target occluded? 0
# percentage occluded: 0.12631578947368421
# Bathroom Location 4 Trial 6
# target occluded? 0
# percentage occluded: 0.288135593220339
# Kitchen Location 3 Trial 6
# target occluded? 0
# percentage occluded: 0.23404255319148937
# Bedroom Location 1 Trial 9
# target occluded? 0
# percentage occluded: 0.0684931506849315
# Bedroom Location 3 Trial 1
# target occluded? 0
# percentage occluded: 0.08108108108108109
# Kitchen Location 2 Trial 5
# target occluded? 0
# percentage occluded: 0.15625
# Guest Bedroom Location 1 Trial 4
# target occluded? 0
# percentage occluded: 0.17708333333333334
# Guest Bedroom Location 4 Trial 3
# target occluded? 0
# percentage occluded: 0.17708333333333334
# Living Room Location 1 Trial 5
# target occluded? 0
# percentage occluded: 0.12962962962962962
# Bedroom Location 1 Trial 7
# target occluded? 0
# percentage occluded: 0.11688311688311688
# Guest Bedroom Location 2 Trial 2
# target occluded? 0
# percentage occluded: 0.17708333333333334
# Kitchen Location 3 Trial 3
# target occluded? 0
# percentage occluded: 0.24468085106382978
# Living Room Location 3 Trial 1
# target occluded? 1
# percentage occluded: 0.21100917431192662
# Bedroom Location 1 Trial 4
# target occluded? 0
# percentage occluded: 0.0958904109589041
# Bedroom Location 2 Trial 6
# target occluded? 0
# percentage occluded: 0.13333333333333333
# Bathroom Location 4 Trial 3
# target occluded? 0
# percentage occluded: 0.21311475409836064
# Living Room Location 4 Trial 2
# target occluded? 0
# percentage occluded: 0.2972972972972973
# Kitchen Location 5 Trial 6
# target occluded? 0
# percentage occluded: 0.1827956989247312
# Living Room Location 1 Trial 7
# target occluded? 0
# percentage occluded: 0.12962962962962962
# Bedroom Location 4 Trial 6
# target occluded? 0
# percentage occluded: 0.05263157894736842
# Studio Location 1 Trial 2
# target occluded? 0
# percentage occluded: 0.029850746268656716
# Studio Location 5 Trial 7
# target occluded? 0
# percentage occluded: 0.09230769230769231
# Studio Location 5 Trial 4
# target occluded? 0
# percentage occluded: 0.140625
# Living Room Location 4 Trial 8
# target occluded? 0
# percentage occluded: 0.29357798165137616
# Studio Location 5 Trial 6
# target occluded? 0
# percentage occluded: 0.10144927536231885
# Bedroom Location 2 Trial 2
# target occluded? 0
# percentage occluded: 0.19480519480519481
# Bathroom Location 3 Trial 2
# target occluded? 0
# percentage occluded: 0.1935483870967742
# Bathroom Location 1 Trial 1
# target occluded? 0
# percentage occluded: 0.1746031746031746
# Bathroom Location 1 Trial 4
# target occluded? 0
# percentage occluded: 0.2542372881355932
# Living Room Location 1 Trial 9
# target occluded? 0
# percentage occluded: 0.14285714285714285
# Guest Bedroom Location 3 Trial 6
# target occluded? 0
# percentage occluded: 0.11458333333333333
# Guest Bedroom Location 5 Trial 7
# target occluded? 0
# percentage occluded: 0.06382978723404255
# Living Room Location 3 Trial 3
# target occluded? 0
# percentage occluded: 0.168141592920354
# Living Room Location 1 Trial 4
# target occluded? 0
# percentage occluded: 0.15454545454545454
# Guest Bedroom Location 2 Trial 9
# target occluded? 0
# percentage occluded: 0.16666666666666666
# Bedroom Location 3 Trial 2
# target occluded? 0
# percentage occluded: 0.0547945205479452
# Studio Location 1 Trial 3
# target occluded? 0
# percentage occluded: 0.046153846153846156
# Kitchen Location 4 Trial 2
# target occluded? 0
# percentage occluded: 0.22340425531914893
# Guest Bedroom Location 1 Trial 10
# target occluded? 0
# percentage occluded: 0.22916666666666666
# Guest Bedroom Location 1 Trial 7
# target occluded? 0
# percentage occluded: 0.22340425531914893
# Kitchen Location 3 Trial 8
# target occluded? 0
# percentage occluded: 0.24468085106382978
# Kitchen Location 4 Trial 3
# target occluded? 0
# percentage occluded: 0.15789473684210525
# Living Room Location 2 Trial 10
# target occluded? 0
# percentage occluded: 0.26126126126126126
# Studio Location 4 Trial 8
# target occluded? 0
# percentage occluded: 0.19696969696969696
# Studio Location 2 Trial 4
# target occluded? 0
# percentage occluded: 0.13432835820895522
# Bathroom Location 1 Trial 10
# target occluded? 0
# percentage occluded: 0.1774193548387097
# Studio Location 5 Trial 1
# target occluded? 0
# percentage occluded: 0.12121212121212122
# Bedroom Location 4 Trial 4
# target occluded? 0
# percentage occluded: 0.07792207792207792
# Kitchen Location 1 Trial 4
# target occluded? 0
# percentage occluded: 0.16842105263157894
# Bedroom Location 1 Trial 5
# target occluded? 0
# percentage occluded: 0.1038961038961039
# Living Room Location 3 Trial 4
# target occluded? 0
# percentage occluded: 0.22018348623853212

# %%
locations_tagged[locations_tagged['scene'] == 'Guest Bedroom Location 5 Trial 10']
# Out:
#                                 scene       object  object_idx         x  \
# 0   Guest Bedroom Location 5 Trial 10    Juice Box           0  1.815701
# 1   Guest Bedroom Location 5 Trial 10     Soda Can           1 -0.257768
# 2   Guest Bedroom Location 5 Trial 10     Crayon 1           2 -2.096002
# 3   Guest Bedroom Location 5 Trial 10     Notebook           3 -0.410877
# 4   Guest Bedroom Location 5 Trial 10       Eraser           4 -0.819050
# ..                                ...          ...         ...       ...
# 90  Guest Bedroom Location 5 Trial 10  Takeout Box          90  1.274587
# 91  Guest Bedroom Location 5 Trial 10     Block 10          91 -0.837748
# 92  Guest Bedroom Location 5 Trial 10      Tea Box          92 -1.527747
# 93  Guest Bedroom Location 5 Trial 10      Block 4          93  1.449727
# 94  Guest Bedroom Location 5 Trial 10         Gold          94 -1.715373
#
#            y         z   r_polar  theta_polar  x_pos_pixel_360  \
# 0  -0.440673  2.524845  0.623452    -0.140762           4909.0
# 1  -1.650431  0.573016 -0.422725    -1.207035           3545.0
# 2  -1.465555  2.204020 -0.760283    -0.449020           3105.0
# 3  -0.893913 -0.332960 -2.251824    -1.036567           1160.0
# 4  -0.938475 -0.266358 -1.885213    -0.828269           1638.0
# ..       ...       ...       ...          ...              ...
# 90 -1.641329  2.550072  0.463507    -0.522383           4700.0
# 91 -1.037320  1.250800 -0.590148    -0.603340           3327.0
# 92 -1.641756  0.277691 -1.390994    -0.813244           2282.0
# 93 -1.289594 -0.397374  1.838328    -0.709061           6493.0
# 94 -0.876749  2.419787 -0.616670    -0.287404           3292.0
#
#     y_pos_pixel_360                        location occluded
# 0            2232.0  [-0.005111, 1.259327, 10.3356]        0
# 1            3622.0  [2.310593, 0.049569, 8.678365]        0
# 2            2633.0  [1.065534, 0.234445, 6.559614]        0
# 3            3399.0  [3.229079, 0.806087, 8.703205]        0
# 4            3128.0  [3.242605, 0.761525, 8.289856]        0
# ..              ...                             ...      ...
# 90           2729.0  [0.074698, 0.058671, 9.799809]        1
# 91           2835.0   [1.757654, 0.66268, 7.978346]        0
# 92           3108.0  [2.845752, 0.058244, 7.489387]        0
# 93           2972.0  [2.932751, 0.410406, 10.54119]        0
# 94           2423.0  [0.780284, 0.823251, 6.891376]        0
#
# [95 rows x 12 columns]
